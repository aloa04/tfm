# %% [markdown]
# # SET UP DATA

# %%
import pandas as pd                 # For dataframe handling
import numpy as np                  # For matrix and list computations
import matplotlib.pyplot as plt     # For advanced graphse
import seaborn as sns  # For hi level, Pandas oriented, graphics
import scipy.stats as stats  # For statistical inference 
from pandas.api.types import CategoricalDtype

# %%
# loading the dataset to pandas DataFrame
url = 'https://raw.githubusercontent.com/aloa04/tfm/main/data/DATASET_HUTJ.csv'
ds = pd.read_csv(url,sep=';', decimal=',', encoding='latin-1')
ds
# Out:
#          NM_ORGANIZATIONESP STD_N_HR_TYPEESP   Año  AñoMes  STD_ID_PERSON  \
# 0      Hospital de TORREJON         Empleado  2018  201801        1000148
# 1      Hospital de TORREJON         Empleado  2018  201801        1001312
# 2      Hospital de TORREJON         Empleado  2018  201801        1002094
# 3      Hospital de TORREJON         Empleado  2018  201801        1002518
# 4      Hospital de TORREJON         Empleado  2018  201801        1003521
# ...                     ...              ...   ...     ...            ...
# 61104  Hospital de TORREJON         Empleado  2022  202207        1030771
# 61105  Hospital de TORREJON         Empleado  2022  202207        1030772
# 61106  Hospital de TORREJON         Empleado  2022  202207        1030777
# 61107  Hospital de TORREJON         Empleado  2022  202207        1030782
# 61108  Hospital de TORREJON         Empleado  2022  202207        1030783
#
#       STD_N_GENDERESP  Núm. Periodo SSP_ID_CONT_INTERN  \
# 0               Mujer             2                189
# 1               Varón             2                100
# 2               Varón             2                100
# 3               Mujer             2                189
# 4               Varón             2                100
# ...               ...           ...                ...
# 61104           Mujer             1               402R
# 61105           Mujer             1               402R
# 61106           Varón             1               402V
# 61107           Mujer             1               402R
# 61108           Mujer             1               402V
#
#                          SSP_NM_CONT_INESP Fecha Inicio  ...  \
# 0      INDEFINIDO TP COMPL TRANSF DE TEMPO   03/05/2010  ...
# 1         ORDINARIO INDEFINIDO TP COMPLETO   04/11/2010  ...
# 2         ORDINARIO INDEFINIDO TP COMPLETO   16/05/2011  ...
# 3      INDEFINIDO TP COMPL TRANSF DE TEMPO   03/10/2011  ...
# 4         ORDINARIO INDEFINIDO TP COMPLETO   27/06/2011  ...
# ...                                    ...          ...  ...
# 61104                  EVENTUAL (REFUERZO)   05/07/2022  ...
# 61105                  EVENTUAL (REFUERZO)   08/07/2022  ...
# 61106          EVENTUAL (SUST. VACACIONES)   06/07/2022  ...
# 61107                  EVENTUAL (REFUERZO)   08/07/2022  ...
# 61108          EVENTUAL (SUST. VACACIONES)   06/07/2022  ...
#
#              STD_N_WL_TYPEESP STD_WORK_LOCESP CSP_N_COLECTIVO STD_DT_BIRTH  \
# 0      Atención Especializada       HospitalA      Estructura   17/04/1982
# 1      Atención Especializada       HospitalA      Estructura   15/08/1966
# 2      Atención Especializada       HospitalA      Estructura   20/02/1983
# 3      Atención Especializada       HospitalA      Estructura   12/10/1983
# 4      Atención Especializada       HospitalA      Estructura   09/07/1966
# ...                       ...             ...             ...          ...
# 61104  Atención Especializada       HospitalA       Refuerzos   23/07/1990
# 61105  Atención Especializada       HospitalA       Refuerzos   22/10/1995
# 61106  Atención Especializada       HospitalA   Sustituciones   16/06/1981
# 61107  Atención Especializada       HospitalA       Refuerzos   22/05/1976
# 61108  Atención Especializada       HospitalA   Sustituciones   07/04/2004
#
#       Edad    RangoEdad Nacionalidad SSP_ID_MINUSVALIA  \
# 0       41        41-50     Española                -2
# 1       57    Más de 50     Española                -2
# 2       40        25-40     Española                -2
# 3       40        25-40     Española                -2
# 4       57    Más de 50     Española                -2
# ...    ...          ...          ...               ...
# 61104   33        25-40     Española                -2
# 61105   28        25-40     Española                -2
# 61106   42        41-50     Española                -2
# 61107   47        41-50     Española                -2
# 61108   19  Menos de 25     Española                -2
#
#       Nombre de la minusvalia : Span Activos
# 0                          Sin Valor       1
# 1                          Sin Valor       1
# 2                          Sin Valor       1
# 3                          Sin Valor       1
# 4                          Sin Valor       1
# ...                              ...     ...
# 61104                      Sin Valor       1
# 61105                      Sin Valor       1
# 61106                      Sin Valor       1
# 61107                      Sin Valor       1
# 61108                      Sin Valor       1
#
# [61109 rows x 26 columns]

# %% [markdown]
# ## Data Transformation

# %%
ds.columns
# Out:
# Index(['NM_ORGANIZATIONESP', 'STD_N_HR_TYPEESP', 'Año', 'AñoMes',
#        'STD_ID_PERSON', 'STD_N_GENDERESP', 'Núm. Periodo',
#        'SSP_ID_CONT_INTERN', 'SSP_NM_CONT_INESP', 'Fecha Inicio',
#        'Fecha_Inicio_contra', 'Fecha_Fin_contra', 'SSP_NO_DEFINIDO',
#        'CSP_N_AG_CATEGOR', 'CSP_NM_CATEGORESP', 'STD_N_WU_TYPEESP',
#        'STD_N_WL_TYPEESP', 'STD_WORK_LOCESP', 'CSP_N_COLECTIVO',
#        'STD_DT_BIRTH', 'Edad', 'RangoEdad', 'Nacionalidad',
#        'SSP_ID_MINUSVALIA', 'Nombre de la minusvalia : Span', 'Activos'],
#       dtype='object')

# %%
ds = ds.rename(columns={'Año':'Anyo', 'AñoMes':'AnyoMes', 'Núm. Periodo':'Num_Periodo'})

# %%
ds = ds.drop(ds[ds["STD_N_GENDERESP"]=='Valor no dado de alta en maestro'].index)

# %%
ds
# Out:
#          NM_ORGANIZATIONESP STD_N_HR_TYPEESP  Anyo  AnyoMes  STD_ID_PERSON  \
# 0      Hospital de TORREJON         Empleado  2018   201801        1000148
# 1      Hospital de TORREJON         Empleado  2018   201801        1001312
# 2      Hospital de TORREJON         Empleado  2018   201801        1002094
# 3      Hospital de TORREJON         Empleado  2018   201801        1002518
# 4      Hospital de TORREJON         Empleado  2018   201801        1003521
# ...                     ...              ...   ...      ...            ...
# 61104  Hospital de TORREJON         Empleado  2022   202207        1030771
# 61105  Hospital de TORREJON         Empleado  2022   202207        1030772
# 61106  Hospital de TORREJON         Empleado  2022   202207        1030777
# 61107  Hospital de TORREJON         Empleado  2022   202207        1030782
# 61108  Hospital de TORREJON         Empleado  2022   202207        1030783
#
#       STD_N_GENDERESP  Num_Periodo SSP_ID_CONT_INTERN  \
# 0               Mujer            2                189
# 1               Varón            2                100
# 2               Varón            2                100
# 3               Mujer            2                189
# 4               Varón            2                100
# ...               ...          ...                ...
# 61104           Mujer            1               402R
# 61105           Mujer            1               402R
# 61106           Varón            1               402V
# 61107           Mujer            1               402R
# 61108           Mujer            1               402V
#
#                          SSP_NM_CONT_INESP Fecha Inicio  ...  \
# 0      INDEFINIDO TP COMPL TRANSF DE TEMPO   03/05/2010  ...
# 1         ORDINARIO INDEFINIDO TP COMPLETO   04/11/2010  ...
# 2         ORDINARIO INDEFINIDO TP COMPLETO   16/05/2011  ...
# 3      INDEFINIDO TP COMPL TRANSF DE TEMPO   03/10/2011  ...
# 4         ORDINARIO INDEFINIDO TP COMPLETO   27/06/2011  ...
# ...                                    ...          ...  ...
# 61104                  EVENTUAL (REFUERZO)   05/07/2022  ...
# 61105                  EVENTUAL (REFUERZO)   08/07/2022  ...
# 61106          EVENTUAL (SUST. VACACIONES)   06/07/2022  ...
# 61107                  EVENTUAL (REFUERZO)   08/07/2022  ...
# 61108          EVENTUAL (SUST. VACACIONES)   06/07/2022  ...
#
#              STD_N_WL_TYPEESP STD_WORK_LOCESP CSP_N_COLECTIVO STD_DT_BIRTH  \
# 0      Atención Especializada       HospitalA      Estructura   17/04/1982
# 1      Atención Especializada       HospitalA      Estructura   15/08/1966
# 2      Atención Especializada       HospitalA      Estructura   20/02/1983
# 3      Atención Especializada       HospitalA      Estructura   12/10/1983
# 4      Atención Especializada       HospitalA      Estructura   09/07/1966
# ...                       ...             ...             ...          ...
# 61104  Atención Especializada       HospitalA       Refuerzos   23/07/1990
# 61105  Atención Especializada       HospitalA       Refuerzos   22/10/1995
# 61106  Atención Especializada       HospitalA   Sustituciones   16/06/1981
# 61107  Atención Especializada       HospitalA       Refuerzos   22/05/1976
# 61108  Atención Especializada       HospitalA   Sustituciones   07/04/2004
#
#       Edad    RangoEdad Nacionalidad SSP_ID_MINUSVALIA  \
# 0       41        41-50     Española                -2
# 1       57    Más de 50     Española                -2
# 2       40        25-40     Española                -2
# 3       40        25-40     Española                -2
# 4       57    Más de 50     Española                -2
# ...    ...          ...          ...               ...
# 61104   33        25-40     Española                -2
# 61105   28        25-40     Española                -2
# 61106   42        41-50     Española                -2
# 61107   47        41-50     Española                -2
# 61108   19  Menos de 25     Española                -2
#
#       Nombre de la minusvalia : Span Activos
# 0                          Sin Valor       1
# 1                          Sin Valor       1
# 2                          Sin Valor       1
# 3                          Sin Valor       1
# 4                          Sin Valor       1
# ...                              ...     ...
# 61104                      Sin Valor       1
# 61105                      Sin Valor       1
# 61106                      Sin Valor       1
# 61107                      Sin Valor       1
# 61108                      Sin Valor       1
#
# [61104 rows x 26 columns]

# %% [markdown]
# # Algoritmo de limpieza

# %%
ds.sort_values("STD_ID_PERSON", inplace = True)
ds
# Out:
#          NM_ORGANIZATIONESP STD_N_HR_TYPEESP  Anyo  AnyoMes  STD_ID_PERSON  \
# 46392  Hospital de TORREJON         Empleado  2021   202108        1000016
# 45145  Hospital de TORREJON         Empleado  2021   202107        1000016
# 17339  Hospital de TORREJON         Empleado  2019   201908        1000016
# 41541  Hospital de TORREJON         Empleado  2021   202104        1000016
# 18496  Hospital de TORREJON         Empleado  2019   201909        1000016
# ...                     ...              ...   ...      ...            ...
# 61104  Hospital de TORREJON         Empleado  2022   202207        1030771
# 61105  Hospital de TORREJON         Empleado  2022   202207        1030772
# 61106  Hospital de TORREJON         Empleado  2022   202207        1030777
# 61107  Hospital de TORREJON         Empleado  2022   202207        1030782
# 61108  Hospital de TORREJON         Empleado  2022   202207        1030783
#
#       STD_N_GENDERESP  Num_Periodo SSP_ID_CONT_INTERN  \
# 46392           Mujer            2                200
# 45145           Mujer            2                200
# 17339           Mujer            2                200
# 41541           Mujer            2                200
# 18496           Mujer            2                200
# ...               ...          ...                ...
# 61104           Mujer            1               402R
# 61105           Mujer            1               402R
# 61106           Varón            1               402V
# 61107           Mujer            1               402R
# 61108           Mujer            1               402V
#
#                          SSP_NM_CONT_INESP Fecha Inicio  ...  \
# 46392  ORDINARIO A TIEMPO PARCIAL INDEFINI   01/07/2019  ...
# 45145  ORDINARIO A TIEMPO PARCIAL INDEFINI   01/07/2019  ...
# 17339  ORDINARIO A TIEMPO PARCIAL INDEFINI   01/07/2019  ...
# 41541  ORDINARIO A TIEMPO PARCIAL INDEFINI   01/07/2019  ...
# 18496  ORDINARIO A TIEMPO PARCIAL INDEFINI   01/07/2019  ...
# ...                                    ...          ...  ...
# 61104                  EVENTUAL (REFUERZO)   05/07/2022  ...
# 61105                  EVENTUAL (REFUERZO)   08/07/2022  ...
# 61106          EVENTUAL (SUST. VACACIONES)   06/07/2022  ...
# 61107                  EVENTUAL (REFUERZO)   08/07/2022  ...
# 61108          EVENTUAL (SUST. VACACIONES)   06/07/2022  ...
#
#              STD_N_WL_TYPEESP STD_WORK_LOCESP CSP_N_COLECTIVO STD_DT_BIRTH  \
# 46392  Atención Especializada       HospitalA      Estructura   01/10/1984
# 45145  Atención Especializada       HospitalA      Estructura   01/10/1984
# 17339  Atención Especializada       HospitalA      Estructura   01/10/1984
# 41541  Atención Especializada       HospitalA      Estructura   01/10/1984
# 18496  Atención Especializada       HospitalA      Estructura   01/10/1984
# ...                       ...             ...             ...          ...
# 61104  Atención Especializada       HospitalA       Refuerzos   23/07/1990
# 61105  Atención Especializada       HospitalA       Refuerzos   22/10/1995
# 61106  Atención Especializada       HospitalA   Sustituciones   16/06/1981
# 61107  Atención Especializada       HospitalA       Refuerzos   22/05/1976
# 61108  Atención Especializada       HospitalA   Sustituciones   07/04/2004
#
#       Edad    RangoEdad Nacionalidad SSP_ID_MINUSVALIA  \
# 46392   39        25-40     Española                -2
# 45145   39        25-40     Española                -2
# 17339   39        25-40     Española                -2
# 41541   39        25-40     Española                -2
# 18496   39        25-40     Española                -2
# ...    ...          ...          ...               ...
# 61104   33        25-40     Española                -2
# 61105   28        25-40     Española                -2
# 61106   42        41-50     Española                -2
# 61107   47        41-50     Española                -2
# 61108   19  Menos de 25     Española                -2
#
#       Nombre de la minusvalia : Span Activos
# 46392                      Sin Valor       1
# 45145                      Sin Valor       1
# 17339                      Sin Valor       1
# 41541                      Sin Valor       1
# 18496                      Sin Valor       1
# ...                              ...     ...
# 61104                      Sin Valor       1
# 61105                      Sin Valor       1
# 61106                      Sin Valor       1
# 61107                      Sin Valor       1
# 61108                      Sin Valor       1
#
# [61104 rows x 26 columns]

# %%
ds = ds.drop(columns="AnyoMes")
ds = ds.drop(columns="Anyo")

ds
# Out:
#          NM_ORGANIZATIONESP STD_N_HR_TYPEESP  STD_ID_PERSON STD_N_GENDERESP  \
# 46392  Hospital de TORREJON         Empleado        1000016           Mujer
# 45145  Hospital de TORREJON         Empleado        1000016           Mujer
# 17339  Hospital de TORREJON         Empleado        1000016           Mujer
# 41541  Hospital de TORREJON         Empleado        1000016           Mujer
# 18496  Hospital de TORREJON         Empleado        1000016           Mujer
# ...                     ...              ...            ...             ...
# 61104  Hospital de TORREJON         Empleado        1030771           Mujer
# 61105  Hospital de TORREJON         Empleado        1030772           Mujer
# 61106  Hospital de TORREJON         Empleado        1030777           Varón
# 61107  Hospital de TORREJON         Empleado        1030782           Mujer
# 61108  Hospital de TORREJON         Empleado        1030783           Mujer
#
#        Num_Periodo SSP_ID_CONT_INTERN                    SSP_NM_CONT_INESP  \
# 46392            2                200  ORDINARIO A TIEMPO PARCIAL INDEFINI
# 45145            2                200  ORDINARIO A TIEMPO PARCIAL INDEFINI
# 17339            2                200  ORDINARIO A TIEMPO PARCIAL INDEFINI
# 41541            2                200  ORDINARIO A TIEMPO PARCIAL INDEFINI
# 18496            2                200  ORDINARIO A TIEMPO PARCIAL INDEFINI
# ...            ...                ...                                  ...
# 61104            1               402R                  EVENTUAL (REFUERZO)
# 61105            1               402R                  EVENTUAL (REFUERZO)
# 61106            1               402V          EVENTUAL (SUST. VACACIONES)
# 61107            1               402R                  EVENTUAL (REFUERZO)
# 61108            1               402V          EVENTUAL (SUST. VACACIONES)
#
#       Fecha Inicio Fecha_Inicio_contra Fecha_Fin_contra  ...  \
# 46392   01/07/2019          01/07/2019       31/10/2021  ...
# 45145   01/07/2019          01/07/2019       31/10/2021  ...
# 17339   01/07/2019          01/07/2019       31/10/2021  ...
# 41541   01/07/2019          01/07/2019       31/10/2021  ...
# 18496   01/07/2019          01/07/2019       31/10/2021  ...
# ...            ...                 ...              ...  ...
# 61104   05/07/2022          05/07/2022       30/09/2022  ...
# 61105   08/07/2022          08/07/2022       31/08/2022  ...
# 61106   06/07/2022          06/07/2022       30/09/2022  ...
# 61107   08/07/2022          08/07/2022       31/08/2022  ...
# 61108   06/07/2022          06/07/2022       31/07/2022  ...
#
#              STD_N_WL_TYPEESP STD_WORK_LOCESP CSP_N_COLECTIVO STD_DT_BIRTH  \
# 46392  Atención Especializada       HospitalA      Estructura   01/10/1984
# 45145  Atención Especializada       HospitalA      Estructura   01/10/1984
# 17339  Atención Especializada       HospitalA      Estructura   01/10/1984
# 41541  Atención Especializada       HospitalA      Estructura   01/10/1984
# 18496  Atención Especializada       HospitalA      Estructura   01/10/1984
# ...                       ...             ...             ...          ...
# 61104  Atención Especializada       HospitalA       Refuerzos   23/07/1990
# 61105  Atención Especializada       HospitalA       Refuerzos   22/10/1995
# 61106  Atención Especializada       HospitalA   Sustituciones   16/06/1981
# 61107  Atención Especializada       HospitalA       Refuerzos   22/05/1976
# 61108  Atención Especializada       HospitalA   Sustituciones   07/04/2004
#
#       Edad    RangoEdad Nacionalidad SSP_ID_MINUSVALIA  \
# 46392   39        25-40     Española                -2
# 45145   39        25-40     Española                -2
# 17339   39        25-40     Española                -2
# 41541   39        25-40     Española                -2
# 18496   39        25-40     Española                -2
# ...    ...          ...          ...               ...
# 61104   33        25-40     Española                -2
# 61105   28        25-40     Española                -2
# 61106   42        41-50     Española                -2
# 61107   47        41-50     Española                -2
# 61108   19  Menos de 25     Española                -2
#
#        Nombre de la minusvalia : Span Activos
# 46392                       Sin Valor       1
# 45145                       Sin Valor       1
# 17339                       Sin Valor       1
# 41541                       Sin Valor       1
# 18496                       Sin Valor       1
# ...                               ...     ...
# 61104                       Sin Valor       1
# 61105                       Sin Valor       1
# 61106                       Sin Valor       1
# 61107                       Sin Valor       1
# 61108                       Sin Valor       1
#
# [61104 rows x 24 columns]

# %%
ds = ds.drop_duplicates()
ds
# Out:
#          NM_ORGANIZATIONESP STD_N_HR_TYPEESP  STD_ID_PERSON STD_N_GENDERESP  \
# 46392  Hospital de TORREJON         Empleado        1000016           Mujer
# 37842  Hospital de TORREJON         Empleado        1000026           Mujer
# 52498  Hospital de TORREJON         Empleado        1000107           Varón
# 31631  Hospital de TORREJON         Empleado        1000125           Mujer
# 25444  Hospital de TORREJON         Empleado        1000146           Mujer
# ...                     ...              ...            ...             ...
# 61104  Hospital de TORREJON         Empleado        1030771           Mujer
# 61105  Hospital de TORREJON         Empleado        1030772           Mujer
# 61106  Hospital de TORREJON         Empleado        1030777           Varón
# 61107  Hospital de TORREJON         Empleado        1030782           Mujer
# 61108  Hospital de TORREJON         Empleado        1030783           Mujer
#
#        Num_Periodo SSP_ID_CONT_INTERN                    SSP_NM_CONT_INESP  \
# 46392            2                200  ORDINARIO A TIEMPO PARCIAL INDEFINI
# 37842            1                100     ORDINARIO INDEFINIDO TP COMPLETO
# 52498            2                100     ORDINARIO INDEFINIDO TP COMPLETO
# 31631            1                100     ORDINARIO INDEFINIDO TP COMPLETO
# 25444            1               402R                  EVENTUAL (REFUERZO)
# ...            ...                ...                                  ...
# 61104            1               402R                  EVENTUAL (REFUERZO)
# 61105            1               402R                  EVENTUAL (REFUERZO)
# 61106            1               402V          EVENTUAL (SUST. VACACIONES)
# 61107            1               402R                  EVENTUAL (REFUERZO)
# 61108            1               402V          EVENTUAL (SUST. VACACIONES)
#
#       Fecha Inicio Fecha_Inicio_contra Fecha_Fin_contra  ...  \
# 46392   01/07/2019          01/07/2019       31/10/2021  ...
# 37842   01/01/2019          01/01/2019       01/01/4000  ...
# 52498   01/01/2019          01/01/2019       01/01/4000  ...
# 31631   01/02/2020          01/02/2020       11/08/2020  ...
# 25444   03/03/2020          03/03/2020       04/03/2020  ...
# ...            ...                 ...              ...  ...
# 61104   05/07/2022          05/07/2022       30/09/2022  ...
# 61105   08/07/2022          08/07/2022       31/08/2022  ...
# 61106   06/07/2022          06/07/2022       30/09/2022  ...
# 61107   08/07/2022          08/07/2022       31/08/2022  ...
# 61108   06/07/2022          06/07/2022       31/07/2022  ...
#
#              STD_N_WL_TYPEESP STD_WORK_LOCESP CSP_N_COLECTIVO STD_DT_BIRTH  \
# 46392  Atención Especializada       HospitalA      Estructura   01/10/1984
# 37842  Atención Especializada       HospitalA      Estructura   22/11/1982
# 52498  Atención Especializada       HospitalA      Estructura   04/12/1972
# 31631  Atención Especializada       HospitalA      Estructura   29/01/1985
# 25444  Atención Especializada       HospitalA       Refuerzos   26/06/1974
# ...                       ...             ...             ...          ...
# 61104  Atención Especializada       HospitalA       Refuerzos   23/07/1990
# 61105  Atención Especializada       HospitalA       Refuerzos   22/10/1995
# 61106  Atención Especializada       HospitalA   Sustituciones   16/06/1981
# 61107  Atención Especializada       HospitalA       Refuerzos   22/05/1976
# 61108  Atención Especializada       HospitalA   Sustituciones   07/04/2004
#
#       Edad    RangoEdad Nacionalidad SSP_ID_MINUSVALIA  \
# 46392   39        25-40     Española                -2
# 37842   41        41-50     Española                -2
# 52498   51    Más de 50     Española                -2
# 31631   38        25-40     Española                -2
# 25444   49        41-50     Española                -2
# ...    ...          ...          ...               ...
# 61104   33        25-40     Española                -2
# 61105   28        25-40     Española                -2
# 61106   42        41-50     Española                -2
# 61107   47        41-50     Española                -2
# 61108   19  Menos de 25     Española                -2
#
#        Nombre de la minusvalia : Span Activos
# 46392                       Sin Valor       1
# 37842                       Sin Valor       1
# 52498                       Sin Valor       1
# 31631                       Sin Valor       1
# 25444                       Sin Valor       1
# ...                               ...     ...
# 61104                       Sin Valor       1
# 61105                       Sin Valor       1
# 61106                       Sin Valor       1
# 61107                       Sin Valor       1
# 61108                       Sin Valor       1
#
# [6776 rows x 24 columns]

# %%
import os
os.chdir(r'C:\Users\Chemagdlc\Desktop\tfm\notebooks')
os.getcwd()
ds.to_csv('dslf.csv', index=False)
